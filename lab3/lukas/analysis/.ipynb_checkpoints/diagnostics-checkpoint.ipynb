# %%
cd ../../AY121/lab3
# Out:
# /Users/lfinkbeiner/Documents/GitHub/AY121/lab3

# %%
# %matplotlib notebook
# %run synthesis3

# %%
cd lukas
# Out:
# /Users/lfinkbeiner/Documents/GitHub/AY121/lab3/lukas

# %%
sun_h2h = load_saves('../data/last_edition/sun_h2h_746.1_minutes.npz')
sun_hour = load_saves('../data/last_edition/sun_63.73_minutes.npz')
moon_h2h = load_saves('../data/last_edition/moon_h2h_final.npz')
cyg_h2h = load_saves('../data/last_edition/CygA_final.npz')

# %%
cd ..
# Out:
# /Users/lfinkbeiner/Documents/GitHub/AY121/lab3

# %%
lockout_plotter(sun_h2h['stamp'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print('Sun, horizon-to-horizon:')
bounds_pst(sun_h2h['stamp'], 6)
# Out:
# Sun, horizon-to-horizon:
# First datum collected at approximately:	Fri Apr  3 06:35:04 2020
# Last datum collected at approximately:	Fri Apr  3 19:01:09 2020

# %%
print('Moon, horizon-to-horizon:')
bounds_pst(moon_h2h['stamp'])
# Out:
# Moon, horizon-to-horizon:
# First datum collected at approximately:	Wed Apr  1 12:45:09 2020
# Last datum collected at approximately:	Thu Apr  2 03:14:09 2020

# %%
print('Cygnus A, horizon-to-horizon:')
bounds_pst(cyg_h2h['stamp'])
# Out:
# Cygnus A, horizon-to-horizon:
# First datum collected at approximately:	Tue Mar 31 00:22:41 2020
# Last datum collected at approximately:	Tue Mar 31 17:39:44 2020

# %%
print('Sun, single hour:')

shh_t = sun_hour['data'][1]

start_ux = shh_t[0]
start_pst = ugradio.timing.local_time(start_ux)
print('First datum collected at approximately:\t' + start_pst)

end_ux = shh_t[len(shh_t) - 1]
end_pst = ugradio.timing.local_time(end_ux)
print('Last datum collected at approximately:\t' + end_pst)
# Out:
# Sun, single hour:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-254ea0e1b470> in <module>
#       1 print('Sun, single hour:')
# ----> 2 bounds_pst(sun_hour['data'][1], 1)
#
# ~/Documents/GitHub/AY121/lab3/synthesis3.py in bounds_pst(stamp_array, time_index)
#
# IndexError: too many indices for array

# %%
sun_hour['data'][1][0]
# Out:
# 1584028999.2840478
