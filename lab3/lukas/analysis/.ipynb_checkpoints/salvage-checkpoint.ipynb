# %%
cd ../../AY121/lab3
# Out:
# /Users/lfinkbeiner/Documents/GitHub/AY121/lab3

# %%
# %matplotlib notebook
# %run synthesis3

# %%
cd lukas
# Out:
# /Users/lfinkbeiner/Documents/GitHub/AY121/lab3/lukas

# %%
sun_hour = load_saves('../data/last_edition/sun_63.73_minutes.npz')
moon_h2h = load_saves('../data/last_edition/moon_h2h_final.npz')
cyg_h2h = load_saves('../data/last_edition/CygA_final.npz')
sun_h2h = load_saves('../data/last_edition/sun_h2h_746.1_minutes.npz')

# %%
cd ..
# Out:
# /Users/lfinkbeiner/Documents/GitHub/AY121/lab3

# %%
def fr(v_s, N):
    return np.linspace(-v_s / 2, v_s / 2, num=N)

# %%
v_m = moon_h2h['data'][0]
t_m = moon_h2h['data'][1]

v_c = cyg_h2h['data'][0]
t_c = cyg_h2h['data'][1]

# %%
def fringe_fft(v, xB):
    x = fr(1, len(v)) * 1000
    F = np.fft.fft(v)
    P = np.abs(F) ** 2
    filtered = np.array([min(P[1:])])
    filtered = np.append(filtered, P[1:], axis=0)
    pp_skeleton(x, filtered, xB, xLabel='Frequency [mHz]', yLabel = r'Power [Arbitrary Units]')
    
def fringe_plot(v):
    fig = plt.figure(figsize=(6,3))
    plt.subplots_adjust(left=.15, bottom=.15, right=.95, top=.9)
    ax = fig.add_subplot(111)

    ax.tick_params(axis="x", labelsize=12)
    ax.tick_params(axis="y", labelsize=12)
    
    L = len(v)
    x = np.linspace(300, L * 600 - 300, L)
    
    ax.plot(x, np.multiply(v, 1000))
    
    plt.xlabel('Elapsed Time [s]', fontsize=12)
    plt.ylabel('Fringe Frequency [mHz]', fontsize=12)
    
    plt.show()

# %%
#print(len(v_m[0:600]))
fringe_fft(v_c, (-.05, .05))
# Out:
# 0
# <img src="data:image/png;base64,..." width="600">

# %%
#plt.plot(collect_fringes(v_m))

print(max(collect_fringes(v_m)))
fringe_plot(collect_fringes(v_m))

#f_m = collect_fringes(v_m)
#x = np.linspace(300, len(collect_fringes(v_m)) * 600 - 300, len(collect_fringes(v_m)))
#print(len(x))
# Out:
# 0.03422370617696158
# <img src="data:image/png;base64,..." width="600">

# %%
i = 47
print(str(600 * i) + ' seconds to ' + str(600 * (i + 1)) + ' seconds.')
fringe_fft(v_m[i * 600: (i + 1) * 600], (-30, 30))
# Out:
# 28200 seconds to 28800 seconds.
# <img src="data:image/png;base64,..." width="600">

# %%
i = 35
span = v_m[600 * i : 600 * (i + 1) + 1]
print(str(600 * i) + ' seconds to ' + str(600 * (i + 1)) + ' seconds.')
print(collect_fringes(span))
fringe_fft(v_m[i * 600: (i + 1) * 600], (-100, 100))
# Out:
# 21000 seconds to 21600 seconds.
# [0.03255425709515858]
# <img src="data:image/png;base64,..." width="600">

# %%
fringe_plot(collect_fringes(v_c))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# draw a horizontal line on the above plot, indicating where the fringe frequency should be
