# %%
exec(open('synthesis.py').read())

# %% [markdown]
# 5.7 plots

# %%
n = load_saves('data/5-5_5-7.npz')['noise']
PP = load_saves('power_pack.npz')['pack']

# %%
wave1 = normalize(n[0], 90)
print(np.mean(wave1))
print(np.var(wave1))
print(np.std(wave1))
# Out:
# 3.79875
# 412.3663734375
# 20.30680608656861

# %%
hist_gauss(wave1, 20.30680608656861, 64)

# %%
limited_plot(PP[0][0], PP[0][1], 'Frequency (MHz)', r'Magnitude-squared Voltage (V$^2$)', (0, .0008))

# %%
avg = noise_averaged(PP, 32)
limited_plot(PP[0][0], avg, 'Frequency (MHz)', r'Magnitude-squared Voltage (V$^2$)', (0, .0008))

# %% [markdown]
# ACF Plots, Attempt #2

# %%
redos = load_saves('data/redos.npz')
r1 = redos['re1']                                                            
r1c = (r1[100:]).astype(float)

# %%
p1 = power_plot(r1c, 658)
# Out:
# -2500000.0

# %%
#fs = freq_range(6.25e6, 15000, 1)
i1 = invf(p1)
plot(i1[0][600:625], np.real(i1[1][600:625]), r'Time ($\mu$s)', 'Voltage (mV)')
# Out:
# /home/lfinkbeiner/.conda/envs/AY160/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
n_corr = np.correlate(r1c, r1c, mode='full')
print(len(n_corr))
plot_sample(n_corr[:16000], 658)
plot_sample(n_corr[16000:], 658)
# Out:
# 31799

# %%
p_ACF = mini_volt_spec(n_corr, 658)

# %% [markdown]
# 7.3 Power Spectra

# %%
p73 = load_saves('power_pack_7-3.npz')
plot(p73['php'][0], p73['php'][1], 'Frequency (MHz)', r'Magnitude-squared Voltage (V$^2$)')

plot(p73['plp'][0], p73['plp'][1], 'Frequency (MHz)', r'Magnitude-squared Voltage (V$^2$)')

plot(p73['phn'][0], p73['phn'][1], 'Frequency (MHz)', r'Magnitude-squared Voltage (V$^2$)')

plot(p73['pln'][0], p73['pln'][1], 'Frequency (MHz)', r'Magnitude-squared Voltage (V$^2$)')

# %% [markdown]
# 5.4 Leakage Re-do

# %%
b1 = load_saves('data/bundle1.npz')
t1s = b1['stand1'][100:]
t4s = b1['stand4_1'][100:]

# %%
frq = freq_range(6.25e6, 8000, 1)
len(frq)
# Out:
# 8000

# %%
prc4 = power_plot(t4s[:1000], 658, freqs=frq)
# Out:
# -2500000.0

# %%
plot(prc4[0], prc4[1], xnote='Frequency (MHz)', ynote = r'$\log||V^2||$', logv=True)

# %%
prc1 = power_plot(t1s[:1000], 658, freqs=frq)
# Out:
# -625000.0

# %%
plot(prc1[0], prc1[1], xnote='Frequency (MHz)', ynote = r'$\log||V^2||$', logv=True)

# %% [markdown]
# 5.5 Separations

# %%
data5 = load_saves('data/5-5_5-7.npz')

# %%
frq = freq_range(31.25e6, 8000, 1)

# %%
c5 = data5['c5'][100:]
pc5 = power_plot(c5[:1000], 444, freqs=frq)
#plot(prc1[0], prc1[1], xnote='Frequency (MHz)', ynote = r'Magnitude-square Voltage (V$^2$)')
# Out:
# -10500000.0

# %%
c1 = data5['c1'][100:]
pc1 = power_plot(c4[:1000], 444, freqs=frq)
# Out:
# -10500000.0

# %%
len(frq)
# Out:
# 8000
