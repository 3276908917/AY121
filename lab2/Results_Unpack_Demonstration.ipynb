# %%
# %run synthesis

# %%
results = load_saves('data/results.npz')
results
# Out:
# {'calOnMedian': array([6.04529657e+13, 3.46461871e+10, 2.53879609e+10, ...,
#         2.47789582e+10, 2.58308291e+10, 3.53930846e+10]),
#  'calOnMean': array([6.06161856e+13, 4.94497090e+10, 3.72847430e+10, ...,
#         3.61482422e+10, 3.66009026e+10, 4.94172222e+10]),
#  'calOffMedian': array([5.96926399e+13, 3.38740619e+10, 2.48433680e+10, ...,
#         2.41342222e+10, 2.52149751e+10, 3.44630277e+10]),
#  'calOffMean': array([5.97887781e+13, 4.80161996e+10, 3.62799246e+10, ...,
#         3.51687860e+10, 3.59561361e+10, 4.86470779e+10]),
#  'cassOnMedian': array([6.37469928e+13, 3.13575860e+10, 2.16188326e+10, ...,
#         2.13822476e+10, 2.21169638e+10, 3.11761569e+10]),
#  'cassOnMean': array([6.43628410e+13, 4.39340255e+10, 3.10736076e+10, ...,
#         3.11289271e+10, 3.12786031e+10, 4.35233491e+10]),
#  'cassOffMedian': array([6.36498610e+13, 3.07812858e+10, 2.14196793e+10, ...,
#         2.12991892e+10, 2.13798090e+10, 3.13042096e+10]),
# ...

# %%
cal_on_median = results['calOnMedian']
cal_on_mean = results['calOnMean']
cal_off_median = results['calOffMedian']
cal_off_mean = results['calOffMean']
cass_on_median = results['cassOnMedian']
cass_on_mean = results['cassOnMean']
cass_off_median = results['cassOffMedian']
cass_off_mean = results['cassOffMean']
thermal_mean = results['tMean']
thermal_median = results['tMedian']
cold_mean = results['coldMean']

# %%
x = freq_range(62.5e6 / 6, 16000) / 10 ** 6

# %%
pp_skeleton(x, cal_on_mean, (-2, 2), logv=True)

# %%
pp_skeleton(x, cal_off_mean, (-2, 2), logv=True)

# %%
pp_skeleton(x, cal_on_median, (-2, 2), logv=True)

# %%
pp_skeleton(x, cal_off_median, (-2, 2), logv=True)

# %%
pp_skeleton(x, cass_on_mean, (-2, 2), logv=True)

# %%
pp_skeleton(x, cass_off_mean, (-2, 2), logv=True)

# %%
pp_skeleton(x, cass_on_median, (-2, 2), logv=True)

# %%
pp_skeleton(x, cass_off_median, (-2, 2), logv=True)

# %%
pp_skeleton(x, thermal_mean, (-2, 2), logv=True)

# %%
pp_skeleton(x, thermal_median, (-2, 2), logv=True)

# %%
pp_skeleton(x, cold_mean, (-2, 2), logv=True)
